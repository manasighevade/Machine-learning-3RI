# %% [markdown]
# Logistic Regression
#
# Problem Statement: Build a model that can predict the type of Species in Iris Flower Dataset.

# %% [markdown]
# Step1: Data Gathering

# %%
import pandas as pd
path =r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/iris.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
df['species'].unique()
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
# Check for the duplicated rows
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# drop the duplicates
df = df.drop_duplicates()

# %%
# Check for Missing values
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# Separate X and Y features
# X = all the features except speices
# Y = species

# %%
X = df.drop(columns='species')
Y = df[['species']]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# Data cleaning and Data preprocessing(Feature Scaling)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

# create the pipeline
num_pipe = make_pipeline(
    SimpleImputer(strategy='mean'),
    MinMaxScaler()
).set_output(transform='pandas')

# Apply the pipeline and do Fit transform on X
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      0.222222     0.625000      0.067797     0.041667
# 1      0.166667     0.416667      0.067797     0.041667
# 2      0.111111     0.500000      0.050847     0.041667
# 3      0.083333     0.458333      0.084746     0.041667
# 4      0.194444     0.666667      0.067797     0.041667

# %% [markdown]
# Splitting of data into training and testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.8,test_size=0.2,random_state=21)

print(f"xtrain:{xtrain.shape}")
print(f"xtest:{xtest.shape}")
print(f"ytrain:{ytrain.shape}")
print(f"ytest:{ytest.shape}")
# Out:
# xtrain:(119, 4)
# xtest:(30, 4)
# ytrain:(119, 1)
# ytest:(30, 1)

# %% [markdown]
# Build the Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# f:\newww\Machine Learning\repository\venv\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9159663865546218

# %% [markdown]
# Evaluation Metrics

# %%
from sklearn.metrics import ConfusionMatrixDisplay,classification_report
ConfusionMatrixDisplay.from_estimator(model,xtest,ytest)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
ypreds = model.predict(xtest)
print(classification_report(ytest,ypreds))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       1.00      0.92      0.96        12
#    virginica       0.88      1.00      0.93         7
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
from sklearn.metrics import f1_score
f1_test = f1_score(ytest,ypreds,average='macro')
f1_test
# Out:
# 0.9632850241545894

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,xtrain,ytrain,cv=3,scoring='f1_macro')
scores
# Out:
# f:\newww\Machine Learning\repository\venv\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# f:\newww\Machine Learning\repository\venv\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# f:\newww\Machine Learning\repository\venv\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.76623377, 1.        , 0.8968254 ])

# %%
scores.mean()
# Out:
# np.float64(0.8876863876863877)

# %% [markdown]
# Model f1_score is greater than 80, however , cross validation scores are greater than 80. We will consider this model for final predictions

# %% [markdown]
# Save the pipeline and also save the model

# %%
import joblib
joblib.dump(num_pipe,"pre.joblib")
joblib.dump(model,"model.joblib")
# Out:
# ['model.joblib']

# %% [markdown]
# Load the saved models and pipelines

# %%
pre2 = joblib.load("pre.joblib")
model2 = joblib.load("model.joblib")

# %%
pre2
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('minmaxscaler', MinMaxScaler())])

# %%
model2
# Out:
# LogisticRegression()

# %%
path2 = r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/iris_sample.csv"
xnew = pd.read_csv(path2)
xnew.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.5          2.5           4.0          1.3
# 1           6.9          3.1           5.1          2.3
# 2           5.1          2.5           3.0          1.1
# 3           4.4          2.9           NaN          0.2
# 4           5.9          3.0           5.1          1.8

# %%
xnew_pre  = num_pipe.transform(xnew)
xnew_pre
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0       0.333333     0.208333      0.508475     0.500000
# 1       0.722222     0.458333      0.694915     0.916667
# 2       0.222222     0.208333      0.338983     0.416667
# 3       0.027778     0.375000      0.465931     0.041667
# 4       0.444444     0.416667      0.694915     0.708333
# 5       0.333333     0.625000      0.050847     0.041667
# 6       0.361111     0.441555      0.440678     0.500000
# 7       0.611111     0.416667      0.711864     0.791667
# 8       0.277778     0.708333      0.084746     0.041667
# 9       0.222222     0.583333      0.084746     0.456096
# 10      0.500000     0.333333      0.508475     0.500000
# 11      0.333333     0.166667      0.457627     0.375000
# 12      0.944444     0.416667      0.864407     0.916667
# 13      0.722222     0.458333      0.661017     0.583333
# 14      0.472222     0.083333      0.677966     0.583333

# %%
final_preds = model2.predict(xnew_pre)
final_preds
# Out:
# array(['versicolor', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'virginica', 'versicolor'],
#       dtype=object)

# %%
xnew.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.5          2.5           4.0          1.3
# 1           6.9          3.1           5.1          2.3
# 2           5.1          2.5           3.0          1.1
# 3           4.4          2.9           NaN          0.2
# 4           5.9          3.0           5.1          1.8

# %%
xnew['Species_Predicted'] = final_preds
xnew.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width Species_Predicted
# 0           5.5          2.5           4.0          1.3        versicolor
# 1           6.9          3.1           5.1          2.3         virginica
# 2           5.1          2.5           3.0          1.1        versicolor
# 3           4.4          2.9           NaN          0.2            setosa
# 4           5.9          3.0           5.1          1.8         virginica

# %%
## save the results to csv file
xnew.to_csv("Species Predicted.csv",index=False)
